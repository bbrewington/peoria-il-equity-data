# %%
from get_dei_data import run_scrape

# %%
df = run_scrape(
    url_list_file_path='../data/business_pages.txt',
    pages_dir_path='../data/pages',
    use_local=True)

output_csv_file_path = '../data/business_pages_parsed.csv'
print(f'Saving to {output_csv_file_path}')
df.to_csv(output_csv_file_path, index=False)
# Out:
# Reading contents from local file
#   Reading: ../data/pages/2349.html
# Reading contents from local file
#   Reading: ../data/pages/88501.html
# Reading contents from local file
#   Reading: ../data/pages/88508.html
# Reading contents from local file
#   Reading: ../data/pages/81923.html
# Reading contents from local file
#   Reading: ../data/pages/88535.html
# Reading contents from local file
#   Reading: ../data/pages/88533.html
# Reading contents from local file
#   Reading: ../data/pages/88449.html
# Reading contents from local file
#   Reading: ../data/pages/88455.html
# Reading contents from local file
#   Reading: ../data/pages/88538.html
# Reading contents from local file
#   Reading: ../data/pages/88485.html
# Reading contents from local file
#   Reading: ../data/pages/88530.html
# Reading contents from local file
#   Reading: ../data/pages/88738.html
# Reading contents from local file
#   Reading: ../data/pages/88523.html
# Reading contents from local file
# ...

# %%
df
# Out:
#                              business_information_raw  \
# 0   \nBusiness Information\nName: AFE Construction...
# 0   \nBusiness Information\nName: Amigos 1 Inc--Am...
# 0   \nBusiness Information\nName: Better 2 Maintai...
# 0   \nBusiness Information\nName: BUDDY'S GROUNDS ...
# 0   \nBusiness Information\nName: Cafe Santa Rosa ...
# ..                                                ...
# 0   \nBusiness Information\nName: V. Marie Creatio...
# 0   \nBusiness Information\nName: Westside Environ...
# 0   \nBusiness Information\nName: Will Heating & C...
# 0   \nBusiness Information\nName: World On Wheels ...
# 0   \nBusiness Information\nName: Your Lives Matte...
#
#                                                Name                Contact  \
# 0                             AFE Construction, LLC        Monica Arbuckle
# 0                  Amigos 1 Inc--Amigos Auto Repair           Rudy Sanchez
# 0                            Better 2 Maintain, LLC         Denise Neumann
# ...
